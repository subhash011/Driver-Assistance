# %%
import numpy as np
import h5py
import pandas as pd
import math
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
dataset_path = "../dataset/carlos2019b.hdf5"

condition = {"good": 0, "bad": 1, "other": -1}
dataset = []

def sample_data(name, obj):
    d = defaultdict(None)
    for (name, value) in obj.attrs.items():
        if(isinstance(value, bytes)):
            value = value.decode('utf-8')
        d[name] = value
    return d

def sensor_data(items):
    d = defaultdict(lambda: np.array([]))
    for (name, value) in items:
        d[name] = value[0:]
    return d

with h5py.File(dataset_path, "r") as f:
    i = 0
    for (name, value) in f['samples'].items():
        send = sensor_data(value.items())
        smpl = sample_data(name, value)
        dataset.append({**smpl, **send})
carlos2019b = pd.DataFrame(dataset)
carlos2019b
# Out:
#      condition                                 event              placement  \
# 0         good  af97e26d-d273-4cdf-823e-9512a0a15757                Console
# 1          NaN  e7250d71-00d4-4a28-95c3-0093b63e9e7c          Left door top
# 2          NaN  24bb858e-aa25-4c4f-bb73-35895d8904d1              Left door
# 3          NaN  af6bbb39-4b3a-4500-b4c7-ebd7b65329eb                Copilot
# 4          NaN  5794dfea-1dd6-4ee5-9198-242de74036d9             Right door
# ...        ...                                   ...                    ...
# 1404       NaN  947a4a24-9b56-4f21-8225-94a4da436968                Console
# 1405      good  62293c82-da5d-4322-8fc9-cab2384a7d02  Console between seats
# 1406       bad  519432f8-7ea6-45b4-a88f-04f903b1c059          Console seats
# 1407       NaN  90791568-e66d-4aad-add3-e928fa45f713                Console
# 1408       NaN  fd23c9b5-c782-4eef-9ebe-03d2f6d62561       Copilot trousers
#
#           speed           type                     vehicle  \
# 0      7.916400  Manhole_cover  Chevrolet Express van 2013
# 1      1.438393        Pothole                Kia RIO 2018
# 2      7.068750        Pothole        Peugeot Partner 2013
# 3      0.000000        Pothole        Chevrolet Spark 2013
# 4      0.000000        Pothole        Chevrolet Cruze 2010
# ...         ...            ...                         ...
# 1404   8.022922        Pothole  Chevrolet Express van 2013
# 1405  21.098361    Metal_bumps        Chevrolet Cruze 2010
# 1406  19.067213    Metal_bumps           Honda Accord 2007
# 1407   7.796429        Pothole        Peugeot Partner 2013
# 1408   0.000000        Pothole               VW Derby 2001
#
#                                                   acc_x  \
# 0     [0.47100000000000003, 0.785, 1.059000000000000...
# 1     [-0.588, -0.628, -0.392, -0.47100000000000003,...
# 2     [3.06, 3.02, 3.2560000000000002, 3.452, 3.4130...
# 3     [-7.9239999999999995, -7.767, -7.845, -8.041, ...
# 4     [5.643, 5.871, 5.871, 5.871, 5.752999999999999...
# ...                                                 ...
# 1404  [-0.0, -0.078, -0.196, -0.196, -0.039, 0.039, ...
# 1405  [-0.47100000000000003, -0.628, -0.118000000000...
# 1406  [-0.392, 1.53, 1.255, 0.196, -0.11800000000000...
# 1407  [-1.177, -0.157, -0.588, 0.235, 1.334, 1.37300...
# 1408  [-7.296, -7.492000000000001, -6.78600000000000...
#
#                                                   acc_y  \
# 0     [-0.431, -0.0, -0.431, -0.431, 0.039, -0.235, ...
# 1     [7.257000000000001, 7.061, 7.1, 6.982, 6.825, ...
# 2     [9.218, 9.022, 9.101, 9.375, 9.257, 9.022, 9.1...
# 3     [4.236000000000001, 4.001, 3.648, 3.177, 2.864...
# 4     [-0.924, -0.551, -0.551, -0.551, -0.335, -0.56...
# ...                                                 ...
# 1404  [-8.12, -8.081, -7.9239999999999995, -8.081, -...
# 1405  [2.354, 2.9810000000000003, 2.314, 2.707, 2.43...
# 1406  [-8.512, -8.316, -9.101, -8.708, -8.394, -9.21...
# 1407  [-0.902, -0.078, -0.51, -0.431, -0.392, -0.706...
# 1408  [-0.157, 0.157, 0.51, 1.0979999999999999, 1.41...
#
#                                                   acc_z  depth   dim1   dim2  \
# 0     [11.062000000000001, 10.827, 10.356, 10.748, 1...    NaN    NaN    NaN
# 1     [-6.629, -7.022, -6.7860000000000005, -6.669, ...    4.0   79.0   25.0
# 2     [3.53, 3.53, 3.373, 3.57, 3.452, 3.687, 3.53, ...    6.5   65.0   43.0
# 3     [5.727, 5.57, 5.492000000000001, 5.41299999999...    6.0   56.0   40.0
# 4     [7.59, 7.382000000000001, 7.382000000000001, 7...    6.0   82.0   34.0
# ...                                                 ...    ...    ...    ...
# 1404  [5.766, 5.766, 5.727, 6.002000000000001, 5.845...   16.0  110.0   59.0
# 1405  [10.982999999999999, 10.552, 10.513, 10.434000...    NaN    NaN    NaN
# 1406  [6.159, 6.041, 6.002000000000001, 5.8839999999...    NaN    NaN    NaN
# 1407  [11.297, 11.415, 10.395, 10.395, 10.9829999999...    5.0   80.0   60.0
# 1408  [8.551, 8.316, 7.806, 7.257000000000001, 7.257...    6.0  178.0  116.0
#
#                                                   gyr_x  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.0...
# ...                                                 ...
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#                                                   gyr_y  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.0...
# ...                                                 ...
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#                                                   gyr_z
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [0.026000000000000002, 0.026000000000000002, 0...
# ...                                                 ...
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
# [1409 rows x 15 columns]
